# %%
import pandas as pd
import matplotlib as mt
from sklearn.model_selection import train_test_split

# %%
dataset=pd.read_csv("/content/austin_weather.csv")
dataset
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
dataset.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
dataset.columns
# Out:
# Index(['Date', 'TempHighF', 'TempAvgF', 'TempLowF', 'DewPointHighF',
#        'DewPointAvgF', 'DewPointLowF', 'HumidityHighPercent',
#        'HumidityAvgPercent', 'HumidityLowPercent',
#        'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
#        'SeaLevelPressureLowInches', 'VisibilityHighMiles',
#        'VisibilityAvgMiles', 'VisibilityLowMiles', 'WindHighMPH', 'WindAvgMPH',
#        'WindGustMPH', 'PrecipitationSumInches', 'Events'],
#       dtype='object')

# %%
dataset.drop(["Date","TempAvgF","DewPointHighF","DewPointAvgF","DewPointLowF","HumidityHighPercent","HumidityLowPercent",'SeaLevelPressureHighInches', 'SeaLevelPressureAvgInches',
       'SeaLevelPressureLowInches','VisibilityHighMiles',
       'VisibilityAvgMiles', 'VisibilityLowMiles','WindHighMPH','WindGustMPH','Events'],axis=1,inplace=True)

# %%
dataset
# Out:
#       TempHighF  TempLowF HumidityAvgPercent WindAvgMPH PrecipitationSumInches
# 0            74        45                 75          4                   0.46
# 1            56        39                 68          6                      0
# 2            58        32                 52          3                      0
# 3            61        31                 56          4                      0
# 4            58        41                 71          2                      T
# ...         ...       ...                ...        ...                    ...
# 1314        103        75                 54          5                      0
# 1315        105        76                 54          5                      0
# 1316        107        77                 51          4                      0
# 1317        106        79                 48          4                      0
# 1318         99        77                 43          4                      0
#
# [1319 rows x 5 columns]

# %%
dataset.isnull().sum()
# Out:
# TempHighF                 0
# TempLowF                  0
# HumidityAvgPercent        0
# WindAvgMPH                0
# PrecipitationSumInches    0
# dtype: int64

# %%
dataset['PrecipitationSumInches']
dataset.head(10)
# Out:
#    TempHighF  TempLowF HumidityAvgPercent WindAvgMPH PrecipitationSumInches
# 0         74        45                 75          4                   0.46
# 1         56        39                 68          6                      0
# 2         58        32                 52          3                      0
# 3         61        31                 56          4                      0
# 4         58        41                 71          2                      T
# 5         57        39                 63          3                      0
# 6         60        45                 65          1                      T
# 7         62        40                 64          2                      T
# 8         64        36                 76          5                      0
# 9         44        35                 60          5                      0
